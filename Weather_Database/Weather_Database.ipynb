# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000, 90.000, size = 2000)
lngs = np.random.uniform(-180.000, 180.000, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lats_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lats_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities

cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 768

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold the weather data

city_data = []

# Print the beginning of the logging

print("Beginning Data retrieval      ")
print("------------------------------")

# Create counter.

record_count = 1

set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
  
    # Add 1 to the record count
    
    record_count +=1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data retrieval
# ------------------------------
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | tiznit
# Processing Record 3 of Set 1 | lebu
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | thompson
# Processing Record 7 of Set 1 | carnarvon
# Processing Record 8 of Set 1 | tuktoyaktuk
# Processing Record 9 of Set 1 | northport
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | khatanga
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | fairbanks
# Processing Record 14 of Set 1 | bilibino
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | estacion coahuila
# Processing Record 17 of Set 1 | port alfred
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | nanortalik
# Processing Record 20 of Set 1 | kyshtovka
# Processing Record 21 of Set 1 | qaanaaq
# Processing Record 22 of Set 1 | bengkulu
# Processing Record 23 of Set 1 | porbandar
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | niquelandia
# Processing Record 26 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | kosel
# Processing Record 29 of Set 1 | sinnamary
# Processing Record 30 of Set 1 | praia da vitoria
# Processing Record 31 of Set 1 | olafsvik
# Processing Record 32 of Set 1 | bredasdorp
# Processing Record 33 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 35 of Set 1 | kawalu
# Processing Record 36 of Set 1 | guaranda
# Processing Record 37 of Set 1 | hearst
# Processing Record 38 of Set 1 | avarua
# Processing Record 39 of Set 1 | qasigiannguit
# Processing Record 40 of Set 1 | pontianak
# Processing Record 41 of Set 1 | jalu
# Processing Record 42 of Set 1 | medicine hat
# Processing Record 43 of Set 1 | albany
# Processing Record 44 of Set 1 | longyearbyen
# Processing Record 45 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 1 | swinoujscie
# Processing Record 47 of Set 1 | polessk
# Processing Record 48 of Set 1 | dunedin
# Processing Record 49 of Set 1 | ixtapa
# Processing Record 50 of Set 1 | nanuque
# Processing Record 1 of Set 2 | ulladulla
# Processing Record 2 of Set 2 | mahebourg
# Processing Record 3 of Set 2 | cayenne
# Processing Record 4 of Set 2 | mataura
# Processing Record 5 of Set 2 | dikson
# Processing Record 6 of Set 2 | lompoc
# Processing Record 7 of Set 2 | frontera
# Processing Record 8 of Set 2 | alofi
# Processing Record 9 of Set 2 | linhares
# Processing Record 10 of Set 2 | hovd
# Processing Record 11 of Set 2 | chachapoyas
# Processing Record 12 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 2 | hilo
# Processing Record 14 of Set 2 | victoria
# Processing Record 15 of Set 2 | kavieng
# Processing Record 16 of Set 2 | bata
# Processing Record 17 of Set 2 | tres picos
# Processing Record 18 of Set 2 | codrington
# Processing Record 19 of Set 2 | dhidhdhoo
# Processing Record 20 of Set 2 | hobart
# Processing Record 21 of Set 2 | khunti
# Processing Record 22 of Set 2 | luderitz
# Processing Record 23 of Set 2 | punta arenas
# Processing Record 24 of Set 2 | camacupa
# Processing Record 25 of Set 2 | klaksvik
# Processing Record 26 of Set 2 | guerrero negro
# Processing Record 27 of Set 2 | koygorodok
# Processing Record 28 of Set 2 | hualmay
# Processing Record 29 of Set 2 | ribeira grande
# Processing Record 30 of Set 2 | montes claros
# Processing Record 31 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 2 | tequila
# Processing Record 33 of Set 2 | barrow
# Processing Record 34 of Set 2 | bathsheba
# Processing Record 35 of Set 2 | dongsheng
# Processing Record 36 of Set 2 | omboue
# Processing Record 37 of Set 2 | tasiilaq
# Processing Record 38 of Set 2 | lavrentiya
# Processing Record 39 of Set 2 | quelimane
# Processing Record 40 of Set 2 | talnakh
# Processing Record 41 of Set 2 | evensk
# Processing Record 42 of Set 2 | east london
# Processing Record 43 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 44 of Set 2 | tiksi
# Processing Record 45 of Set 2 | mikkeli
# Processing Record 46 of Set 2 | lixourion
# Processing Record 47 of Set 2 | camopi
# Processing Record 48 of Set 2 | cockburn town
# Processing Record 49 of Set 2 | muswellbrook
# Processing Record 50 of Set 2 | arraial do cabo
# Processing Record 1 of Set 3 | egvekinot
# Processing Record 2 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 3 | bandarbeyla
# Processing Record 4 of Set 3 | puri
# Processing Record 5 of Set 3 | inuvik
# Processing Record 6 of Set 3 | adamas
# Processing Record 7 of Set 3 | port hardy
# Processing Record 8 of Set 3 | saskylakh
# Processing Record 9 of Set 3 | sierra vista
# Processing Record 10 of Set 3 | airai
# Processing Record 11 of Set 3 | nabire
# Processing Record 12 of Set 3 | saint george
# Processing Record 13 of Set 3 | isangel
# Processing Record 14 of Set 3 | koungheul
# Processing Record 15 of Set 3 | mitsamiouli
# Processing Record 16 of Set 3 | hithadhoo
# Processing Record 17 of Set 3 | torbat-e jam
# Processing Record 18 of Set 3 | beboto
# Processing Record 19 of Set 3 | lagoa
# Processing Record 20 of Set 3 | kodiak
# Processing Record 21 of Set 3 | kaitangata
# Processing Record 22 of Set 3 | beyneu
# Processing Record 23 of Set 3 | maragogi
# Processing Record 24 of Set 3 | butaritari
# Processing Record 25 of Set 3 | perth
# Processing Record 26 of Set 3 | donskoye
# Processing Record 27 of Set 3 | hambantota
# Processing Record 28 of Set 3 | mayumba
# Processing Record 29 of Set 3 | bethel
# Processing Record 30 of Set 3 | ilulissat
# Processing Record 31 of Set 3 | matsanga
# City not found. Skipping...
# Processing Record 32 of Set 3 | akyab
# Processing Record 33 of Set 3 | gizo
# Processing Record 34 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 36 of Set 3 | pevek
# Processing Record 37 of Set 3 | upernavik
# Processing Record 38 of Set 3 | the pas
# Processing Record 39 of Set 3 | nome
# Processing Record 40 of Set 3 | dunmore east
# Processing Record 41 of Set 3 | hasaki
# Processing Record 42 of Set 3 | mattru
# Processing Record 43 of Set 3 | pervomayskiy
# Processing Record 44 of Set 3 | zemio
# Processing Record 45 of Set 3 | bambous virieux
# Processing Record 46 of Set 3 | nikolskoye
# Processing Record 47 of Set 3 | esmeraldas
# Processing Record 48 of Set 3 | atuona
# Processing Record 49 of Set 3 | sao filipe
# Processing Record 50 of Set 3 | sorland
# Processing Record 1 of Set 4 | port elizabeth
# Processing Record 2 of Set 4 | leshukonskoye
# Processing Record 3 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 4 | cabo san lucas
# Processing Record 5 of Set 4 | aswan
# Processing Record 6 of Set 4 | lagos
# Processing Record 7 of Set 4 | san cristobal
# Processing Record 8 of Set 4 | okakarara
# Processing Record 9 of Set 4 | hobyo
# Processing Record 10 of Set 4 | vila do maio
# Processing Record 11 of Set 4 | hamilton
# Processing Record 12 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 4 | mingaora
# Processing Record 14 of Set 4 | green river
# Processing Record 15 of Set 4 | puerto del rosario
# Processing Record 16 of Set 4 | ariquemes
# Processing Record 17 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 18 of Set 4 | mangrol
# Processing Record 19 of Set 4 | new norfolk
# Processing Record 20 of Set 4 | port hedland
# Processing Record 21 of Set 4 | yellowknife
# Processing Record 22 of Set 4 | namatanai
# Processing Record 23 of Set 4 | morges
# Processing Record 24 of Set 4 | puerto ayora
# Processing Record 25 of Set 4 | cap malheureux
# Processing Record 26 of Set 4 | vitim
# Processing Record 27 of Set 4 | monze
# Processing Record 28 of Set 4 | tallahassee
# Processing Record 29 of Set 4 | luanda
# Processing Record 30 of Set 4 | waipawa
# Processing Record 31 of Set 4 | algiers
# Processing Record 32 of Set 4 | kranuan
# Processing Record 33 of Set 4 | qaqortoq
# Processing Record 34 of Set 4 | pizarro
# Processing Record 35 of Set 4 | skjervoy
# Processing Record 36 of Set 4 | liverpool
# Processing Record 37 of Set 4 | sioux lookout
# Processing Record 38 of Set 4 | saint-philippe
# Processing Record 39 of Set 4 | carballo
# Processing Record 40 of Set 4 | flinders
# Processing Record 41 of Set 4 | abong mbang
# Processing Record 42 of Set 4 | leningradskiy
# Processing Record 43 of Set 4 | luganville
# Processing Record 44 of Set 4 | ahipara
# Processing Record 45 of Set 4 | te anau
# Processing Record 46 of Set 4 | mbandaka
# Processing Record 47 of Set 4 | villazon
# Processing Record 48 of Set 4 | nara
# Processing Record 49 of Set 4 | narsaq
# Processing Record 50 of Set 4 | bereda
# Processing Record 1 of Set 5 | saldanha
# Processing Record 2 of Set 5 | provideniya
# Processing Record 3 of Set 5 | abha
# Processing Record 4 of Set 5 | shadegan
# Processing Record 5 of Set 5 | port macquarie
# Processing Record 6 of Set 5 | disa
# Processing Record 7 of Set 5 | nishihara
# Processing Record 8 of Set 5 | svetlyy
# Processing Record 9 of Set 5 | batagay-alyta
# Processing Record 10 of Set 5 | padang
# Processing Record 11 of Set 5 | lerwick
# Processing Record 12 of Set 5 | terney
# Processing Record 13 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 14 of Set 5 | chimbote
# Processing Record 15 of Set 5 | atasu
# Processing Record 16 of Set 5 | mar del plata
# Processing Record 17 of Set 5 | port blair
# Processing Record 18 of Set 5 | avera
# Processing Record 19 of Set 5 | coquimbo
# Processing Record 20 of Set 5 | kieta
# Processing Record 21 of Set 5 | cidreira
# Processing Record 22 of Set 5 | vilya
# Processing Record 23 of Set 5 | abu dhabi
# Processing Record 24 of Set 5 | el sauzal
# Processing Record 25 of Set 5 | ancud
# Processing Record 26 of Set 5 | obo
# Processing Record 27 of Set 5 | teguldet
# Processing Record 28 of Set 5 | paita
# Processing Record 29 of Set 5 | torbay
# Processing Record 30 of Set 5 | santa isabel do rio negro
# Processing Record 31 of Set 5 | pucallpa
# Processing Record 32 of Set 5 | sayyan
# Processing Record 33 of Set 5 | praya
# Processing Record 34 of Set 5 | richards bay
# Processing Record 35 of Set 5 | say
# Processing Record 36 of Set 5 | synya
# Processing Record 37 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 38 of Set 5 | iquique
# Processing Record 39 of Set 5 | sigulda
# Processing Record 40 of Set 5 | gangotri
# City not found. Skipping...
# Processing Record 41 of Set 5 | kununurra
# Processing Record 42 of Set 5 | faanui
# Processing Record 43 of Set 5 | wajima
# Processing Record 44 of Set 5 | hermanus
# Processing Record 45 of Set 5 | svetlogorsk
# Processing Record 46 of Set 5 | aksha
# Processing Record 47 of Set 5 | port lincoln
# Processing Record 48 of Set 5 | yar-sale
# Processing Record 49 of Set 5 | gamba
# Processing Record 50 of Set 5 | vila franca do campo
# Processing Record 1 of Set 6 | buala
# Processing Record 2 of Set 6 | antonina
# Processing Record 3 of Set 6 | berlevag
# Processing Record 4 of Set 6 | nago
# Processing Record 5 of Set 6 | muroto
# Processing Record 6 of Set 6 | laguna
# Processing Record 7 of Set 6 | amalapuram
# Processing Record 8 of Set 6 | santiago del estero
# Processing Record 9 of Set 6 | northam
# Processing Record 10 of Set 6 | honavar
# Processing Record 11 of Set 6 | daru
# Processing Record 12 of Set 6 | mackenzie
# Processing Record 13 of Set 6 | burica
# City not found. Skipping...
# Processing Record 14 of Set 6 | barinas
# Processing Record 15 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 18 of Set 6 | iisalmi
# Processing Record 19 of Set 6 | the valley
# Processing Record 20 of Set 6 | tepeaca
# Processing Record 21 of Set 6 | sao joao da barra
# Processing Record 22 of Set 6 | georgetown
# Processing Record 23 of Set 6 | roald
# Processing Record 24 of Set 6 | gorontalo
# Processing Record 25 of Set 6 | chuy
# Processing Record 26 of Set 6 | cherskiy
# Processing Record 27 of Set 6 | cervo
# Processing Record 28 of Set 6 | vilhena
# Processing Record 29 of Set 6 | eten
# Processing Record 30 of Set 6 | kedgwick
# Processing Record 31 of Set 6 | katsuura
# Processing Record 32 of Set 6 | zhanatas
# City not found. Skipping...
# Processing Record 33 of Set 6 | tura
# Processing Record 34 of Set 6 | khilok
# Processing Record 35 of Set 6 | hofn
# Processing Record 36 of Set 6 | saint-pierre
# Processing Record 37 of Set 6 | jijiga
# Processing Record 38 of Set 6 | chilca
# Processing Record 39 of Set 6 | jimenez
# Processing Record 40 of Set 6 | salalah
# Processing Record 41 of Set 6 | college
# Processing Record 42 of Set 6 | rognan
# Processing Record 43 of Set 6 | lianzhou
# Processing Record 44 of Set 6 | ayabaca
# Processing Record 45 of Set 6 | esperance
# Processing Record 46 of Set 6 | abashiri
# Processing Record 47 of Set 6 | zhezkazgan
# Processing Record 48 of Set 6 | bria
# Processing Record 49 of Set 6 | touros
# Processing Record 50 of Set 6 | scarborough
# Processing Record 1 of Set 7 | hami
# Processing Record 2 of Set 7 | meadow lake
# Processing Record 3 of Set 7 | altay
# Processing Record 4 of Set 7 | inegol
# Processing Record 5 of Set 7 | kahului
# Processing Record 6 of Set 7 | severodvinsk
# Processing Record 7 of Set 7 | plouzane
# Processing Record 8 of Set 7 | patacamaya
# Processing Record 9 of Set 7 | angul
# Processing Record 10 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 7 | bardiyah
# Processing Record 12 of Set 7 | san patricio
# Processing Record 13 of Set 7 | uspenka
# Processing Record 14 of Set 7 | one hundred mile house
# City not found. Skipping...
# Processing Record 15 of Set 7 | pasighat
# Processing Record 16 of Set 7 | miles city
# Processing Record 17 of Set 7 | vanimo
# Processing Record 18 of Set 7 | borogontsy
# Processing Record 19 of Set 7 | sabzevar
# Processing Record 20 of Set 7 | pisco
# Processing Record 21 of Set 7 | sisimiut
# Processing Record 22 of Set 7 | severo-kurilsk
# Processing Record 23 of Set 7 | nelson bay
# Processing Record 24 of Set 7 | olinda
# Processing Record 25 of Set 7 | ekhabi
# Processing Record 26 of Set 7 | vestmannaeyjar
# Processing Record 27 of Set 7 | darlowo
# Processing Record 28 of Set 7 | chokurdakh
# Processing Record 29 of Set 7 | sumoto
# Processing Record 30 of Set 7 | matagami
# Processing Record 31 of Set 7 | kosonsoy
# Processing Record 32 of Set 7 | karakendzha
# City not found. Skipping...
# Processing Record 33 of Set 7 | inowroclaw
# Processing Record 34 of Set 7 | vieques
# Processing Record 35 of Set 7 | castro
# Processing Record 36 of Set 7 | iwanai
# Processing Record 37 of Set 7 | voineasa
# Processing Record 38 of Set 7 | coahuayana
# Processing Record 39 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 7 | ust-kuyga
# Processing Record 41 of Set 7 | clyde river
# Processing Record 42 of Set 7 | hazorasp
# Processing Record 43 of Set 7 | manbij
# Processing Record 44 of Set 7 | quatre cocos
# Processing Record 45 of Set 7 | sitka
# Processing Record 46 of Set 7 | aklavik
# Processing Record 47 of Set 7 | pitiquito
# Processing Record 48 of Set 7 | yurino
# Processing Record 49 of Set 7 | waycross
# Processing Record 50 of Set 7 | okandja
# City not found. Skipping...
# Processing Record 1 of Set 8 | along
# Processing Record 2 of Set 8 | buraydah
# Processing Record 3 of Set 8 | high prairie
# Processing Record 4 of Set 8 | bahia blanca
# Processing Record 5 of Set 8 | tateyama
# Processing Record 6 of Set 8 | arman
# Processing Record 7 of Set 8 | north platte
# Processing Record 8 of Set 8 | senno
# Processing Record 9 of Set 8 | mme
# City not found. Skipping...
# Processing Record 10 of Set 8 | nizhneudinsk
# Processing Record 11 of Set 8 | souillac
# Processing Record 12 of Set 8 | lamar
# Processing Record 13 of Set 8 | muravlenko
# Processing Record 14 of Set 8 | emerald
# Processing Record 15 of Set 8 | gombong
# Processing Record 16 of Set 8 | contrecoeur
# Processing Record 17 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 8 | pangai
# Processing Record 19 of Set 8 | geraldton
# Processing Record 20 of Set 8 | adre
# Processing Record 21 of Set 8 | noyakert
# Processing Record 22 of Set 8 | carmen
# Processing Record 23 of Set 8 | saint-paul
# Processing Record 24 of Set 8 | havre-saint-pierre
# Processing Record 25 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 8 | kikwit
# Processing Record 27 of Set 8 | mutata
# Processing Record 28 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 8 | polovinnoye
# Processing Record 30 of Set 8 | blind river
# Processing Record 31 of Set 8 | basco
# Processing Record 32 of Set 8 | acapulco
# Processing Record 33 of Set 8 | tarija
# Processing Record 34 of Set 8 | bocanda
# Processing Record 35 of Set 8 | jizan
# Processing Record 36 of Set 8 | beckley
# Processing Record 37 of Set 8 | wilmington
# Processing Record 38 of Set 8 | kachiry
# Processing Record 39 of Set 8 | lasa
# Processing Record 40 of Set 8 | agirish
# Processing Record 41 of Set 8 | paralimni
# Processing Record 42 of Set 8 | ponta do sol
# Processing Record 43 of Set 8 | saint-louis
# Processing Record 44 of Set 8 | california city
# Processing Record 45 of Set 8 | muyezerskiy
# Processing Record 46 of Set 8 | pontes e lacerda
# Processing Record 47 of Set 8 | beibei
# Processing Record 48 of Set 8 | palmer
# Processing Record 49 of Set 8 | timmins
# Processing Record 50 of Set 8 | dekoa
# City not found. Skipping...
# Processing Record 1 of Set 9 | smithers
# Processing Record 2 of Set 9 | luwuk
# Processing Record 3 of Set 9 | tabuk
# Processing Record 4 of Set 9 | myitkyina
# Processing Record 5 of Set 9 | grand gaube
# Processing Record 6 of Set 9 | opuwo
# Processing Record 7 of Set 9 | kawana waters
# City not found. Skipping...
# Processing Record 8 of Set 9 | magadan
# Processing Record 9 of Set 9 | barcelos
# Processing Record 10 of Set 9 | mayor pablo lagerenza
# Processing Record 11 of Set 9 | vardo
# Processing Record 12 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 13 of Set 9 | bafata
# Processing Record 14 of Set 9 | barra do garcas
# Processing Record 15 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 9 | fortuna
# Processing Record 17 of Set 9 | dreznica
# Processing Record 18 of Set 9 | elko
# Processing Record 19 of Set 9 | paraiso
# Processing Record 20 of Set 9 | srednekolymsk
# Processing Record 21 of Set 9 | agadez
# Processing Record 22 of Set 9 | coronado
# Processing Record 23 of Set 9 | halifax
# Processing Record 24 of Set 9 | batkovici
# City not found. Skipping...
# Processing Record 25 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 9 | saint anthony
# Processing Record 27 of Set 9 | kulachi
# Processing Record 28 of Set 9 | claremont
# Processing Record 29 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 30 of Set 9 | batemans bay
# Processing Record 31 of Set 9 | jishou
# Processing Record 32 of Set 9 | alanya
# Processing Record 33 of Set 9 | lorengau
# Processing Record 34 of Set 9 | kolosovka
# Processing Record 35 of Set 9 | broken hill
# Processing Record 36 of Set 9 | ishim
# Processing Record 37 of Set 9 | shitanjing
# Processing Record 38 of Set 9 | altamira
# Processing Record 39 of Set 9 | la serena
# Processing Record 40 of Set 9 | maniitsoq
# Processing Record 41 of Set 9 | adrar
# Processing Record 42 of Set 9 | am timan
# Processing Record 43 of Set 9 | pacific grove
# Processing Record 44 of Set 9 | viedma
# Processing Record 45 of Set 9 | turukhansk
# Processing Record 46 of Set 9 | batticaloa
# Processing Record 47 of Set 9 | safaqis
# City not found. Skipping...
# Processing Record 48 of Set 9 | los llanos de aridane
# Processing Record 49 of Set 9 | zharkent
# Processing Record 50 of Set 9 | binzhou
# Processing Record 1 of Set 10 | sobolevo
# Processing Record 2 of Set 10 | zaysan
# Processing Record 3 of Set 10 | yulara
# Processing Record 4 of Set 10 | yeppoon
# Processing Record 5 of Set 10 | belyy yar
# Processing Record 6 of Set 10 | bindura
# Processing Record 7 of Set 10 | girona
# Processing Record 8 of Set 10 | buchanan
# Processing Record 9 of Set 10 | mastic beach
# Processing Record 10 of Set 10 | san quintin
# Processing Record 11 of Set 10 | deputatskiy
# Processing Record 12 of Set 10 | sire
# Processing Record 13 of Set 10 | chunskiy
# Processing Record 14 of Set 10 | marawi
# Processing Record 15 of Set 10 | linxia
# Processing Record 16 of Set 10 | agsu
# City not found. Skipping...
# Processing Record 17 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 18 of Set 10 | maykain
# City not found. Skipping...
# Processing Record 19 of Set 10 | kabarnet
# Processing Record 20 of Set 10 | trincomalee
# Processing Record 21 of Set 10 | raghunathpur
# Processing Record 22 of Set 10 | zamania
# Processing Record 23 of Set 10 | newport
# Processing Record 24 of Set 10 | pozo colorado
# Processing Record 25 of Set 10 | anadyr
# Processing Record 26 of Set 10 | labrea
# Processing Record 27 of Set 10 | chingirlau
# Processing Record 28 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 29 of Set 10 | erzin
# Processing Record 30 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 31 of Set 10 | bati
# Processing Record 32 of Set 10 | kindu
# Processing Record 33 of Set 10 | chunhuhub
# Processing Record 34 of Set 10 | prince rupert
# Processing Record 35 of Set 10 | khani
# Processing Record 36 of Set 10 | pangnirtung
# Processing Record 37 of Set 10 | santa rosa
# Processing Record 38 of Set 10 | alta floresta
# Processing Record 39 of Set 10 | gazli
# Processing Record 40 of Set 10 | keuruu
# Processing Record 41 of Set 10 | benguela
# Processing Record 42 of Set 10 | norman wells
# Processing Record 43 of Set 10 | warri
# Processing Record 44 of Set 10 | houma
# Processing Record 45 of Set 10 | soyo
# Processing Record 46 of Set 10 | inhambane
# Processing Record 47 of Set 10 | kuusamo
# Processing Record 48 of Set 10 | rimoc
# Processing Record 49 of Set 10 | vlore
# Processing Record 50 of Set 10 | mezhdurechensk
# Processing Record 1 of Set 11 | barcelona
# Processing Record 2 of Set 11 | poso
# Processing Record 3 of Set 11 | poum
# Processing Record 4 of Set 11 | bonfim
# Processing Record 5 of Set 11 | velika gorica
# Processing Record 6 of Set 11 | iqaluit
# Processing Record 7 of Set 11 | aktau
# Processing Record 8 of Set 11 | salinopolis
# Processing Record 9 of Set 11 | tavricheskoye
# Processing Record 10 of Set 11 | maldonado
# Processing Record 11 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 12 of Set 11 | mount gambier
# Processing Record 13 of Set 11 | sorong
# Processing Record 14 of Set 11 | kuldiga
# Processing Record 15 of Set 11 | abapo
# Processing Record 16 of Set 11 | mumford
# Processing Record 17 of Set 11 | kunda
# Processing Record 18 of Set 11 | ojinaga
# Processing Record 19 of Set 11 | haines junction
# Processing Record 20 of Set 11 | suntar
# Processing Record 21 of Set 11 | antofagasta
# Processing Record 22 of Set 11 | constitucion
# Processing Record 23 of Set 11 | dingle
# Processing Record 24 of Set 11 | mahibadhoo
# Processing Record 25 of Set 11 | lermontovka
# Processing Record 26 of Set 11 | pechora
# Processing Record 27 of Set 11 | port moresby
# Processing Record 28 of Set 11 | labuhan
# Processing Record 29 of Set 11 | vestmanna
# Processing Record 30 of Set 11 | kudahuvadhoo
# Processing Record 31 of Set 11 | bogorodskoye
# Processing Record 32 of Set 11 | karpogory
# Processing Record 33 of Set 11 | tibati
# Processing Record 34 of Set 11 | tazovskiy
# Processing Record 35 of Set 11 | dali
# Processing Record 36 of Set 11 | trat
# Processing Record 37 of Set 11 | launceston
# Processing Record 38 of Set 11 | arklow
# Processing Record 39 of Set 11 | sungaipenuh
# Processing Record 40 of Set 11 | ahuimanu
# Processing Record 41 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 11 | gat
# Processing Record 43 of Set 11 | nongpoh
# Processing Record 44 of Set 11 | tevriz
# Processing Record 45 of Set 11 | okha
# Processing Record 46 of Set 11 | upata
# Processing Record 47 of Set 11 | puerto baquerizo moreno
# Processing Record 48 of Set 11 | baykit
# Processing Record 49 of Set 11 | islamkot
# Processing Record 50 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 12 | sweetwater
# Processing Record 2 of Set 12 | manono
# Processing Record 3 of Set 12 | moju
# Processing Record 4 of Set 12 | pokhara
# Processing Record 5 of Set 12 | zapolyarnyy
# Processing Record 6 of Set 12 | nouadhibou
# Processing Record 7 of Set 12 | mysen
# Processing Record 8 of Set 12 | thoen
# Processing Record 9 of Set 12 | aksu
# Processing Record 10 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 12 | wanning
# Processing Record 12 of Set 12 | aden
# Processing Record 13 of Set 12 | kupino
# Processing Record 14 of Set 12 | mixtequilla
# City not found. Skipping...
# Processing Record 15 of Set 12 | clarence town
# Processing Record 16 of Set 12 | mecca
# Processing Record 17 of Set 12 | morgan city
# Processing Record 18 of Set 12 | teknaf
# Processing Record 19 of Set 12 | jiuquan
# Processing Record 20 of Set 12 | gardan diwal
# City not found. Skipping...
# Processing Record 21 of Set 12 | sassandra
# Processing Record 22 of Set 12 | grand-santi
# Processing Record 23 of Set 12 | high level
# Processing Record 24 of Set 12 | karaton
# Processing Record 25 of Set 12 | nantucket
# Processing Record 26 of Set 12 | kamenka
# Processing Record 27 of Set 12 | saint-joseph
# Processing Record 28 of Set 12 | gao
# Processing Record 29 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 30 of Set 12 | khor
# Processing Record 31 of Set 12 | faya
# Processing Record 32 of Set 12 | hurghada
# Processing Record 33 of Set 12 | sept-iles
# Processing Record 34 of Set 12 | iskateley
# Processing Record 35 of Set 12 | sahuaripa
# Processing Record 36 of Set 12 | ouesso
# Processing Record 37 of Set 12 | khandyga
# Processing Record 38 of Set 12 | paso de los toros
# Processing Record 39 of Set 12 | port-gentil
# Processing Record 40 of Set 12 | lapithos
# Processing Record 41 of Set 12 | la uribe
# City not found. Skipping...
# Processing Record 42 of Set 12 | cap-aux-meules
# Processing Record 43 of Set 12 | urumqi
# Processing Record 44 of Set 12 | nalut
# Processing Record 45 of Set 12 | panzhihua
# Processing Record 46 of Set 12 | bonthe
# Processing Record 47 of Set 12 | san juan
# Processing Record 48 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 49 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 50 of Set 12 | la seyne-sur-mer
# Processing Record 1 of Set 13 | kuching
# Processing Record 2 of Set 13 | westpunt
# City not found. Skipping...
# Processing Record 3 of Set 13 | charters towers
# Processing Record 4 of Set 13 | tubuala
# Processing Record 5 of Set 13 | ballina
# Processing Record 6 of Set 13 | rio tuba
# Processing Record 7 of Set 13 | general roca
# Processing Record 8 of Set 13 | galle
# Processing Record 9 of Set 13 | muzhi
# Processing Record 10 of Set 13 | yazman
# Processing Record 11 of Set 13 | paamiut
# Processing Record 12 of Set 13 | zhigansk
# Processing Record 13 of Set 13 | pahrump
# Processing Record 14 of Set 13 | abu zabad
# Processing Record 15 of Set 13 | windhoek
# Processing Record 16 of Set 13 | biak
# Processing Record 17 of Set 13 | hanchuan
# Processing Record 18 of Set 13 | ishigaki
# Processing Record 19 of Set 13 | portland
# Processing Record 20 of Set 13 | igarka
# Processing Record 21 of Set 13 | ust-kut
# Processing Record 22 of Set 13 | koungou
# Processing Record 23 of Set 13 | udachnyy
# Processing Record 24 of Set 13 | praia
# Processing Record 25 of Set 13 | la paz
# Processing Record 26 of Set 13 | moerai
# Processing Record 27 of Set 13 | bolshiye uki
# City not found. Skipping...
# Processing Record 28 of Set 13 | marzuq
# Processing Record 29 of Set 13 | kavaratti
# Processing Record 30 of Set 13 | aksarka
# Processing Record 31 of Set 13 | balikpapan
# Processing Record 32 of Set 13 | sydney
# Processing Record 33 of Set 13 | salisbury
# Processing Record 34 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 35 of Set 13 | oussouye
# Processing Record 36 of Set 13 | san lorenzo
# Processing Record 37 of Set 13 | linguere
# Processing Record 38 of Set 13 | umred
# Processing Record 39 of Set 13 | umm lajj
# Processing Record 40 of Set 13 | kruisfontein
# Processing Record 41 of Set 13 | colesville
# Processing Record 42 of Set 13 | koslan
# Processing Record 43 of Set 13 | moree
# Processing Record 44 of Set 13 | skagen
# Processing Record 45 of Set 13 | uray
# Processing Record 46 of Set 13 | deer lake
# Processing Record 47 of Set 13 | tezu
# Processing Record 48 of Set 13 | montrose
# Processing Record 49 of Set 13 | chumikan
# Processing Record 50 of Set 13 | bowen
# Processing Record 1 of Set 14 | tuatapere
# Processing Record 2 of Set 14 | durban
# Processing Record 3 of Set 14 | ha giang
# Processing Record 4 of Set 14 | hanmer springs
# Processing Record 5 of Set 14 | kisesa
# Processing Record 6 of Set 14 | arlit
# Processing Record 7 of Set 14 | bairiki
# Processing Record 8 of Set 14 | bonavista
# Processing Record 9 of Set 14 | barinitas
# Processing Record 10 of Set 14 | juifang
# City not found. Skipping...
# Processing Record 11 of Set 14 | atikokan
# Processing Record 12 of Set 14 | norwich
# Processing Record 13 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 14 of Set 14 | waingapu
# Processing Record 15 of Set 14 | henties bay
# Processing Record 16 of Set 14 | urubicha
# Processing Record 17 of Set 14 | russell
# Processing Record 18 of Set 14 | pedasi
# Processing Record 19 of Set 14 | bosaso
# Processing Record 20 of Set 14 | marion
# Processing Record 21 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 22 of Set 14 | pangody
# Processing Record 23 of Set 14 | hima
# Processing Record 24 of Set 14 | ust-kulom
# Processing Record 25 of Set 14 | aqtobe
# Processing Record 26 of Set 14 | dianopolis
# City not found. Skipping...
# Processing Record 27 of Set 14 | inongo
# Processing Record 28 of Set 14 | chillicothe
# Processing Record 29 of Set 14 | qandala
# Processing Record 30 of Set 14 | norfolk
# Processing Record 31 of Set 14 | kapustin yar-1
# City not found. Skipping...
# Processing Record 32 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 33 of Set 14 | aasiaat
# Processing Record 34 of Set 14 | manta
# Processing Record 35 of Set 14 | boo
# Processing Record 36 of Set 14 | sokoto
# Processing Record 37 of Set 14 | brae
# Processing Record 38 of Set 14 | mollendo
# Processing Record 39 of Set 14 | baghdad
# Processing Record 40 of Set 14 | ijaki
# City not found. Skipping...
# Processing Record 41 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 42 of Set 14 | presidencia roque saenz pena
# Processing Record 43 of Set 14 | codajas
# Processing Record 44 of Set 14 | bima
# Processing Record 45 of Set 14 | fare
# Processing Record 46 of Set 14 | puerto ayacucho
# Processing Record 47 of Set 14 | itoman
# Processing Record 48 of Set 14 | san policarpo
# Processing Record 49 of Set 14 | palm beach
# Processing Record 50 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 1 of Set 15 | vila velha
# Processing Record 2 of Set 15 | meulaboh
# Processing Record 3 of Set 15 | rurrenabaque
# Processing Record 4 of Set 15 | fehergyarmat
# Processing Record 5 of Set 15 | wuwei
# Processing Record 6 of Set 15 | phan thiet
# Processing Record 7 of Set 15 | nuuk
# Processing Record 8 of Set 15 | la ronge
# Processing Record 9 of Set 15 | luba
# Processing Record 10 of Set 15 | caceres
# Processing Record 11 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 12 of Set 15 | tiarei
# Processing Record 13 of Set 15 | belmonte
# Processing Record 14 of Set 15 | shimoda
# Processing Record 15 of Set 15 | caravelas
# Processing Record 16 of Set 15 | ossora
# Processing Record 17 of Set 15 | yunjinghong
# City not found. Skipping...
# Processing Record 18 of Set 15 | tautira
# Processing Record 19 of Set 15 | gumdag
# Processing Record 20 of Set 15 | urdoma
# Processing Record 21 of Set 15 | akdepe
# Processing Record 22 of Set 15 | chimoio
# Processing Record 23 of Set 15 | indramayu
# Processing Record 24 of Set 15 | husavik
# Processing Record 25 of Set 15 | chodavaram
# Processing Record 26 of Set 15 | azimur
# City not found. Skipping...
# Processing Record 27 of Set 15 | murgab
# Processing Record 28 of Set 15 | beringovskiy
# Processing Record 29 of Set 15 | banfora
# Processing Record 30 of Set 15 | taitung
# Processing Record 31 of Set 15 | havoysund
# Processing Record 32 of Set 15 | nemuro
# Processing Record 33 of Set 15 | banes
# Processing Record 34 of Set 15 | krasnovishersk
# Processing Record 35 of Set 15 | casambalangan
# Processing Record 36 of Set 15 | ljungby
# Processing Record 37 of Set 15 | rtyne v podkrkonosi
# Processing Record 38 of Set 15 | plainview
# Processing Record 39 of Set 15 | miroslav
# Processing Record 40 of Set 15 | ocampo
# Processing Record 41 of Set 15 | kaduna
# Processing Record 42 of Set 15 | dwarka
# Processing Record 43 of Set 15 | yellamanchili
# City not found. Skipping...
# Processing Record 44 of Set 15 | port shepstone
# Processing Record 45 of Set 15 | omsukchan
# Processing Record 46 of Set 15 | fairview
# Processing Record 47 of Set 15 | annau
# Processing Record 48 of Set 15 | ponta delgada
# Processing Record 49 of Set 15 | gushikawa
# Processing Record 50 of Set 15 | larsnes
# Processing Record 1 of Set 16 | betsiamites
# Processing Record 2 of Set 16 | santa maria
# Processing Record 3 of Set 16 | saint-augustin
# Processing Record 4 of Set 16 | shibarghan
# City not found. Skipping...
# Processing Record 5 of Set 16 | shingu
# Processing Record 6 of Set 16 | elsdorf
# Processing Record 7 of Set 16 | rocha
# Processing Record 8 of Set 16 | harindanga
# Processing Record 9 of Set 16 | camacha
# Processing Record 10 of Set 16 | camalu
# Processing Record 11 of Set 16 | ngunguru
# Processing Record 12 of Set 16 | roura
# Processing Record 13 of Set 16 | adoni
# Processing Record 14 of Set 16 | qui nhon
# Processing Record 15 of Set 16 | bongaree
# Processing Record 16 of Set 16 | kassala
# Processing Record 17 of Set 16 | mamit
# Processing Record 18 of Set 16 | verkhnetulomskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 696

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Cape Town -33.9258   18.4232     77.41        76           0       14.00
# 1       Tiznit  29.5833   -9.5000     58.23        81          78       10.56
# 2         Lebu -37.6167  -73.6500     62.56        71          37       25.05
# 3        Bluff -46.6000  168.3333     56.19        90         100        2.77
# 4      Rikitea -23.1203 -134.9692     74.17        75          96        7.99
# 5     Thompson  55.7435  -97.8558     21.36        86         100        9.22
# 6    Carnarvon -24.8667  113.6333     71.62        76           0       20.60
# 7  Tuktoyaktuk  69.4541 -133.0374     -9.40        84          20        5.75
# 8    Northport  33.2290  -87.5772     56.25        50           0       10.36
# 9    Jamestown  42.0970  -79.2353     38.79        72         100       17.27
#
#   Country Current Description
# 0      ZA          light rain
# 1      MA          light rain
# 2      CL    scattered clouds
# 3      NZ          light rain
# 4      PF     overcast clouds
# 5      CA          light snow
# 6      AU           clear sky
# 7      CA          few clouds
# 8      US           clear sky
# 9      US                snow

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Cape Town      ZA -33.9258   18.4232     77.41        76           0
# 1       Tiznit      MA  29.5833   -9.5000     58.23        81          78
# 2         Lebu      CL -37.6167  -73.6500     62.56        71          37
# 3        Bluff      NZ -46.6000  168.3333     56.19        90         100
# 4      Rikitea      PF -23.1203 -134.9692     74.17        75          96
# 5     Thompson      CA  55.7435  -97.8558     21.36        86         100
# 6    Carnarvon      AU -24.8667  113.6333     71.62        76           0
# 7  Tuktoyaktuk      CA  69.4541 -133.0374     -9.40        84          20
# 8    Northport      US  33.2290  -87.5772     56.25        50           0
# 9    Jamestown      US  42.0970  -79.2353     38.79        72         100
#
#    Wind Speed Current Description
# 0       14.00          light rain
# 1       10.56          light rain
# 2       25.05    scattered clouds
# 3        2.77          light rain
# 4        7.99     overcast clouds
# 5        9.22          light snow
# 6       20.60           clear sky
# 7        5.75          few clouds
# 8       10.36           clear sky
# 9       17.27                snow

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
